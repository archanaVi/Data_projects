# %% [markdown]
# ## Merge dataframe

# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
#import seaborn as sns
#%matplotlib inline

# %%
df=pd.read_csv('main_data.csv')

# %%
df
# Out:
#            ID                  Name  Age  \
# 0      158023              L. Messi   31
# 1       20801     Cristiano Ronaldo   33
# 2      190871             Neymar Jr   26
# 3      193080                De Gea   27
# 4      192985          K. De Bruyne   27
# 5      183277             E. Hazard   27
# 6      177003             L. Modrić   32
# 7      176580             L. Suárez   31
# 8      155862          Sergio Ramos   32
# 9      200389              J. Oblak   25
# 10     188545        R. Lewandowski   29
# 11     182521              T. Kroos   28
# 12     182493              D. Godín   32
# 13     168542           David Silva   32
# 14     215914              N. Kanté   27
# 15     211110             P. Dybala   24
# 16     202126               H. Kane   24
# 17     194765          A. Griezmann   27
# 18     192448         M. ter Stegen   26
# 19     192119           T. Courtois   26
# 20     189511       Sergio Busquets   29
# 21     179813             E. Cavani   31
# ...

# %%
df.shape
# Out:
# (17918, 15)

# %%
df1=pd.read_csv('id_name_18000.csv')

# %%
df1.shape
# Out:
# (18558, 2)

# %%
#df.set_index('ID').join(df1.set_index('id'))
df1.rename(columns={'id': 'ID'},inplace=True)

# %%
df=df.join(df1.set_index('id'), on='ID')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17918 entries, 0 to 17917
# Data columns (total 16 columns):
# ID                          17918 non-null int64
# Name                        17918 non-null object
# Age                         17918 non-null int64
# Photo                       17918 non-null object
# Nationality                 17918 non-null object
# Overall                     17918 non-null int64
# Potential                   17918 non-null int64
# Club                        17918 non-null object
# Value                       17918 non-null int64
# Wage                        17918 non-null int64
# Preferred Foot              17918 non-null object
# International Reputation    17918 non-null float64
# Jersey Number               17918 non-null float64
# Height                      17918 non-null float64
# Weight                      17918 non-null float64
# name                        11929 non-null object
# dtypes: float64(4), int64(6), object(6)
# ...

# %%
df=df[['ID','Name','name','Age','Photo','Nationality','Overall','Potential','Club','Value','Wage','Preferred Foot','International Reputation','Jersey Number','Height','Weight']]

# %%
df.isna().sum()
# Out:
# ID                             0
# Name                           0
# name                        5989
# Age                            0
# Photo                          0
# Nationality                    0
# Overall                        0
# Potential                      0
# Club                           0
# Value                          0
# Wage                           0
# Preferred Foot                 0
# International Reputation       0
# Jersey Number                  0
# Height                         0
# Weight                         0
# dtype: int64

# %%
df.to_csv('/Users/archanavillalba/Data/everyday_code/Module1_project/final_scraped_list.csv', index=False)

# %%
df.head()
# Out:
#        ID               Name                          name  Age  \
# 0  158023           L. Messi                  Lionel Messi   31
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   33
# 2  190871          Neymar Jr    Neymar da Silva Santos Jr.   26
# 3  193080             De Gea         David De Gea Quintana   27
# 4  192985       K. De Bruyne               Kevin De Bruyne   27
#
#                                             Photo Nationality  Overall  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina       94
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal       94
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil       92
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain       91
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium       91
#
#    Potential                 Club       Value    Wage Preferred Foot  \
# 0         94         FC Barcelona  1105000000  565000           Left
# ...

# %%
df.loc[df.name.isna(),'name']=df.loc[df.name.isna(),'Name']
df[['Name','name']]
# Out:
#                        Name                               name
# 0                  L. Messi                       Lionel Messi
# 1         Cristiano Ronaldo       C. Ronaldo dos Santos Aveiro
# 2                 Neymar Jr         Neymar da Silva Santos Jr.
# 3                    De Gea              David De Gea Quintana
# 4              K. De Bruyne                    Kevin De Bruyne
# 5                 E. Hazard                        Eden Hazard
# 6                 L. Modrić                        Luka Modrić
# 7                 L. Suárez                        Luis Suárez
# 8              Sergio Ramos                Sergio Ramos García
# 9                  J. Oblak                          Jan Oblak
# 10           R. Lewandowski                 Robert Lewandowski
# 11                 T. Kroos                         Toni Kroos
# 12                 D. Godín                        Diego Godín
# 13              David Silva          David Josué Jiménez Silva
# ...

# %%
df=df.drop(['Name'],axis=1)

# %%
df.head()
# Out:
#        ID                          name  Age  \
# 0  158023                  Lionel Messi   31
# 1   20801  C. Ronaldo dos Santos Aveiro   33
# 2  190871    Neymar da Silva Santos Jr.   26
# 3  193080         David De Gea Quintana   27
# 4  192985               Kevin De Bruyne   27
#
#                                             Photo Nationality  Overall  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina       94
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal       94
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil       92
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain       91
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium       91
#
#    Potential                 Club       Value    Wage Preferred Foot  \
# 0         94         FC Barcelona  1105000000  565000           Left
# 1         94             Juventus    77000000  405000          Right
# ...

# %%
df.rename(columns={'name': 'Name'},inplace=True)

# %%
df.to_csv('/Users/archanavillalba/Data/everyday_code/Module1_project/final_data.csv', index=False)
